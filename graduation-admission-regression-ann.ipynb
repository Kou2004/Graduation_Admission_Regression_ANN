# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/graduate-admissions/Admission_Predict.csv
# /kaggle/input/graduate-admissions/Admission_Predict_Ver1.1.csv

# %%
df=pd.read_csv('/kaggle/input/graduate-admissions/Admission_Predict_Ver1.1.csv')
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.drop("Serial No.",axis=1,inplace=True)

# %%
df.head()
X=df.iloc[:,0:7]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_traini=scaler.fit_transform(X_train)
X_testi=scaler.transform(X_test)

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(7,activation="relu",input_dim=7))
model.add(Dense(7,activation="relu"))
model.add(Dense(1,activation='linear'))
model.summary()
# Out:
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_69 (Dense)            (None, 7)                 56
#
#  dense_70 (Dense)            (None, 7)                 56
#
#  dense_71 (Dense)            (None, 1)                 8
#
# =================================================================
# Total params: 120
# Trainable params: 120
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="mean_squared_error",optimizer='sgd')

# %%
model.fit(X_traini,y_train,epochs=120,validation_split=0.2)
# Out:
# Epoch 1/120
# 10/10 [==============================] - 1s 19ms/step - loss: 0.2117 - val_loss: 0.1439
# Epoch 2/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0970 - val_loss: 0.0768
# Epoch 3/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0586 - val_loss: 0.0525
# Epoch 4/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0452 - val_loss: 0.0427
# Epoch 5/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0397 - val_loss: 0.0378
# Epoch 6/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0366 - val_loss: 0.0348
# Epoch 7/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0342 - val_loss: 0.0325
# Epoch 8/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0323 - val_loss: 0.0306
# Epoch 9/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0305 - val_loss: 0.0290
# Epoch 10/120
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0290 - val_loss: 0.0275
# Epoch 11/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0276 - val_loss: 0.0262
# Epoch 12/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0263 - val_loss: 0.0251
# Epoch 13/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0252 - val_loss: 0.0241
# Epoch 14/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0242 - val_loss: 0.0232
# Epoch 15/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0232 - val_loss: 0.0223
# Epoch 16/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0224 - val_loss: 0.0215
# Epoch 17/120
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0216 - val_loss: 0.0209
# Epoch 18/120
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0208 - val_loss: 0.0202
# Epoch 19/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0201 - val_loss: 0.0197
# Epoch 20/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0195 - val_loss: 0.0191
# Epoch 21/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0189 - val_loss: 0.0187
# Epoch 22/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0184 - val_loss: 0.0182
# Epoch 23/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0179 - val_loss: 0.0178
# Epoch 24/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0174 - val_loss: 0.0174
# Epoch 25/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0170 - val_loss: 0.0171
# Epoch 26/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0166 - val_loss: 0.0168
# Epoch 27/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0163 - val_loss: 0.0164
# Epoch 28/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0159 - val_loss: 0.0162
# Epoch 29/120
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0156 - val_loss: 0.0159
# Epoch 30/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0153 - val_loss: 0.0156
# Epoch 31/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0150 - val_loss: 0.0153
# Epoch 32/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0147 - val_loss: 0.0151
# Epoch 33/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0145 - val_loss: 0.0149
# Epoch 34/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0142 - val_loss: 0.0147
# Epoch 35/120
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0140 - val_loss: 0.0145
# Epoch 36/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0138 - val_loss: 0.0143
# Epoch 37/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0136 - val_loss: 0.0142
# Epoch 38/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0134 - val_loss: 0.0140
# Epoch 39/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0132 - val_loss: 0.0138
# Epoch 40/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0130 - val_loss: 0.0137
# Epoch 41/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0128 - val_loss: 0.0135
# Epoch 42/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0127 - val_loss: 0.0134
# Epoch 43/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0125 - val_loss: 0.0133
# Epoch 44/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0124 - val_loss: 0.0131
# Epoch 45/120
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0122 - val_loss: 0.0130
# Epoch 46/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0121 - val_loss: 0.0129
# Epoch 47/120
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0120 - val_loss: 0.0128
# Epoch 48/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0118 - val_loss: 0.0127
# Epoch 49/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0117 - val_loss: 0.0126
# Epoch 50/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0116 - val_loss: 0.0125
# Epoch 51/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0115 - val_loss: 0.0124
# Epoch 52/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0114 - val_loss: 0.0123
# Epoch 53/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0113 - val_loss: 0.0123
# Epoch 54/120
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0112 - val_loss: 0.0122
# Epoch 55/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0111 - val_loss: 0.0121
# Epoch 56/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0110 - val_loss: 0.0120
# Epoch 57/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0109 - val_loss: 0.0120
# Epoch 58/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0109 - val_loss: 0.0119
# Epoch 59/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0108 - val_loss: 0.0118
# Epoch 60/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0107 - val_loss: 0.0118
# Epoch 61/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0106 - val_loss: 0.0117
# Epoch 62/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0106 - val_loss: 0.0116
# Epoch 63/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0105 - val_loss: 0.0116
# Epoch 64/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0104 - val_loss: 0.0115
# Epoch 65/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0104 - val_loss: 0.0115
# Epoch 66/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0103 - val_loss: 0.0114
# Epoch 67/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0102 - val_loss: 0.0114
# Epoch 68/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0102 - val_loss: 0.0113
# Epoch 69/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0101 - val_loss: 0.0113
# Epoch 70/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0101 - val_loss: 0.0112
# Epoch 71/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0100 - val_loss: 0.0112
# Epoch 72/120
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0100 - val_loss: 0.0111
# Epoch 73/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0111
# Epoch 74/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0110
# Epoch 75/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0098 - val_loss: 0.0110
# Epoch 76/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0098 - val_loss: 0.0109
# Epoch 77/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0097 - val_loss: 0.0109
# Epoch 78/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0097 - val_loss: 0.0108
# Epoch 79/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0096 - val_loss: 0.0108
# Epoch 80/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0096 - val_loss: 0.0108
# Epoch 81/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0095 - val_loss: 0.0107
# Epoch 82/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0095 - val_loss: 0.0107
# Epoch 83/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0095 - val_loss: 0.0106
# Epoch 84/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 0.0106
# Epoch 85/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 0.0106
# Epoch 86/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 0.0105
# Epoch 87/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0093 - val_loss: 0.0105
# Epoch 88/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0093 - val_loss: 0.0105
# Epoch 89/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0092 - val_loss: 0.0104
# Epoch 90/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0092 - val_loss: 0.0104
# Epoch 91/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0092 - val_loss: 0.0104
# Epoch 92/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0091 - val_loss: 0.0103
# Epoch 93/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0091 - val_loss: 0.0103
# Epoch 94/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0091 - val_loss: 0.0103
# Epoch 95/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0090 - val_loss: 0.0102
# Epoch 96/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0090 - val_loss: 0.0102
# Epoch 97/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0090 - val_loss: 0.0102
# Epoch 98/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.0102
# Epoch 99/120
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0089 - val_loss: 0.0101
# Epoch 100/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0089 - val_loss: 0.0101
# Epoch 101/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0088 - val_loss: 0.0101
# Epoch 102/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0088 - val_loss: 0.0100
# Epoch 103/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0088 - val_loss: 0.0100
# Epoch 104/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0087 - val_loss: 0.0100
# Epoch 105/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0087 - val_loss: 0.0099
# Epoch 106/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0087 - val_loss: 0.0099
# Epoch 107/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0099
# Epoch 108/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0098
# Epoch 109/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0098
# Epoch 110/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0086 - val_loss: 0.0098
# Epoch 111/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0085 - val_loss: 0.0098
# Epoch 112/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0085 - val_loss: 0.0097
# Epoch 113/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0085 - val_loss: 0.0097
# Epoch 114/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0084 - val_loss: 0.0097
# Epoch 115/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0084 - val_loss: 0.0097
# Epoch 116/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0084 - val_loss: 0.0096
# Epoch 117/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0084 - val_loss: 0.0096
# Epoch 118/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0083 - val_loss: 0.0096
# Epoch 119/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0083 - val_loss: 0.0096
# Epoch 120/120
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0083 - val_loss: 0.0095

# %%
y_pred=model.predict(X_testi)
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 4/4 [==============================] - 0s 2ms/step
# 0.5975862206149546
